# %% [markdown]
# <a href="https://colab.research.google.com/github/arshadb-AI29/Python_Basics_01/blob/main/Practice_Py_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
I want to print the hello world program

# %%
s = "hello"
print(s[::-1])
# Out:
# olleh

# %%
print ("Hi this is Arshad")
# Out:
# Hi this is Arshad

# %%
a=10
b=10
print(a+b)
# Out:
# 20

# %%
student_id= 101
print(student_id)
# Out:
# 101
